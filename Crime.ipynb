# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('crime_data (1).csv')
df
# Out:
#        Arrest Year Arrest Date  Arrest Hour  Age Defendant Race  \
# 0             2021      1/1/21            0   38          BLACK
# 1             2021      1/1/21            0   31          BLACK
# 2             2021      1/1/21            0   35          BLACK
# 3             2021      1/1/21            0   31          BLACK
# 4             2021      1/1/21            0   21          BLACK
# ...            ...         ...          ...  ...            ...
# 15648         2021      9/9/21           18   19          BLACK
# 15649         2021      9/9/21           20   61          BLACK
# 15650         2021      9/9/21           20   21          WHITE
# 15651         2021      9/9/21           21   30          BLACK
# 15652         2021      9/9/21           23   27          BLACK
#
#       Defendant Ethnicity Defendant Sex     Arrest Category  Offense Latitude  \
# 0                 UNKNOWN          MALE  Damage to Property            38.927
# ...

# %%
df.head()
# Out:
#    Arrest Year Arrest Date  Arrest Hour  Age Defendant Race  \
# 0         2021      1/1/21            0   38          BLACK
# 1         2021      1/1/21            0   31          BLACK
# 2         2021      1/1/21            0   35          BLACK
# 3         2021      1/1/21            0   31          BLACK
# 4         2021      1/1/21            0   21          BLACK
#
#   Defendant Ethnicity Defendant Sex     Arrest Category  Offense Latitude  \
# 0             UNKNOWN          MALE  Damage to Property            38.927
# 1        NOT HISPANIC          MALE      Simple Assault            38.925
# 2        NOT HISPANIC          MALE   Weapon Violations            38.900
# 3        NOT HISPANIC          MALE   Weapon Violations            38.849
# 4        NOT HISPANIC          MALE   Weapon Violations            38.882
#
#    Offense Longitude
# 0            -77.006
# 1            -77.033
# 2            -76.930
# 3            -76.976
# 4            -76.925

# %%
df.shape
# Out:
# (15653, 10)

# %%
df.columns
# Out:
# Index(['Arrest Year', 'Arrest Date', 'Arrest Hour', 'Age', 'Defendant Race',
#        'Defendant Ethnicity', 'Defendant Sex', 'Arrest Category',
#        'Offense Latitude', 'Offense Longitude'],
#       dtype='object')

# %%
df.isnull()
# Out:
#        Arrest Year  Arrest Date  Arrest Hour    Age  Defendant Race  \
# 0            False        False        False  False           False
# 1            False        False        False  False           False
# 2            False        False        False  False           False
# 3            False        False        False  False           False
# 4            False        False        False  False           False
# ...            ...          ...          ...    ...             ...
# 15648        False        False        False  False           False
# 15649        False        False        False  False           False
# 15650        False        False        False  False           False
# 15651        False        False        False  False           False
# 15652        False        False        False  False           False
#
#        Defendant Ethnicity  Defendant Sex  Arrest Category  Offense Latitude  \
# ...

# %%
features = ['Arrest Year', 'Arrest Date', 'Arrest Hour', 'Age', 'Defendant Race',
       'Defendant Ethnicity', 'Defendant Sex', 'Arrest Category',
       'Offense Latitude', 'Offense Longitude']

# %%
for feature in features:
    null_check = pd.isnull(df[feature])
    print(df[null_check])
# Out:
# Empty DataFrame
# Columns: [Arrest Year, Arrest Date, Arrest Hour, Age, Defendant Race, Defendant Ethnicity, Defendant Sex, Arrest Category, Offense Latitude, Offense Longitude]
# Index: []
# Empty DataFrame
# Columns: [Arrest Year, Arrest Date, Arrest Hour, Age, Defendant Race, Defendant Ethnicity, Defendant Sex, Arrest Category, Offense Latitude, Offense Longitude]
# Index: []
# Empty DataFrame
# Columns: [Arrest Year, Arrest Date, Arrest Hour, Age, Defendant Race, Defendant Ethnicity, Defendant Sex, Arrest Category, Offense Latitude, Offense Longitude]
# Index: []
# Empty DataFrame
# Columns: [Arrest Year, Arrest Date, Arrest Hour, Age, Defendant Race, Defendant Ethnicity, Defendant Sex, Arrest Category, Offense Latitude, Offense Longitude]
# Index: []
# Empty DataFrame
# Columns: [Arrest Year, Arrest Date, Arrest Hour, Age, Defendant Race, Defendant Ethnicity, Defendant Sex, Arrest Category, Offense Latitude, Offense Longitude]
# Index: []
# Empty DataFrame
# ...

# %%
df = df.dropna()
df.shape
# Out:
# (15632, 10)

# %%
df ['Defendant Race'].unique()
# Out:
# array(['BLACK', 'WHITE', 'UNKNOWN', 'ASIAN', 'MULTIPLE', 'OTHER'],
#       dtype=object)

# %%
df['Arrest Category'].unique()
# Out:
# array(['Damage to Property', 'Simple Assault', 'Weapon Violations',
#        'Narcotics', 'Other Crimes', 'Driving/Boating While Intoxicated',
#        'Traffic Violations', 'Sex Offenses', 'Theft', 'Property Crimes',
#        'Release Violations/Fugitive (Warr)',
#        'Release Violations/Fugitive (Fug)',
#        'Offenses Against Family & Children', 'Liquor Law Violations',
#        'Assault with a Dangerous Weapon', 'Homicide',
#        'Assault on a Police Officer', 'Burglary', 'Vending Violations',
#        'Robbery', 'Motor Vehicle Theft', 'Sex Abuse',
#        'Aggravated Assault', 'Disorderly Conduct', 'Gambling',
#        'Kidnapping', 'Fraud and Financial Crimes',
#        'Fraud and Financial Crimes (Frau)', 'Theft from Auto',
#        'Prostitution', 'Fraud and Financial Crimes (Forg)',
#        'Fraud and Financial Crimes (Coun)'], dtype=object)

# %%
df_sex = df.groupby('Defendant Sex').size().reset_index(name = 'Numbers')
df_sex
# Out:
#   Defendant Sex  Numbers
# 0        FEMALE     3419
# 1          MALE    12207
# 2       UNKNOWN        6

# %%
plt.figure(figsize = (8, 5))
plt.xlabel('Defendant Sex')
plt.title('Arrests by Sex')
plt.ylabel('Numbers')
x = df_sex['Defendant Sex']
y = df_sex['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Defendant Sex.jpg', dpi = 480)

# %%
sns.displot(df['Defendant Sex'], kde = True, bins = 20)

# %%
df_cate = df.groupby('Arrest Category').size().reset_index(name = 'Numbers')
df_cate
# Out:
#                        Arrest Category  Numbers
# 0                   Aggravated Assault       97
# 1          Assault on a Police Officer      346
# 2      Assault with a Dangerous Weapon      570
# 3                             Burglary      133
# 4                   Damage to Property      621
# 5                   Disorderly Conduct       65
# 6    Driving/Boating While Intoxicated      833
# 7           Fraud and Financial Crimes        7
# 8    Fraud and Financial Crimes (Coun)        1
# 9    Fraud and Financial Crimes (Forg)        2
# 10   Fraud and Financial Crimes (Frau)       22
# 11                            Gambling       19
# 12                            Homicide       97
# 13                          Kidnapping       25
# 14               Liquor Law Violations       95
# 15                 Motor Vehicle Theft       22
# 16                           Narcotics      701
# 17  Offenses Against Family & Children      381
# 18                        Other Crimes      940
# ...

# %%
plt.figure(figsize = (40, 10))
plt.xlabel('Arrest Category')
plt.title('Arrests by Category')
plt.ylabel('Numbers')
x = df_cate['Arrest Category']
y = df_cate['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Arrest Category.jpg', dpi = 480)

# %%
sns.displot(df['Arrest Category'], kde = True, bins = 20)

# %%
df_ethn = df.groupby('Defendant Ethnicity').size().reset_index(name = 'Numbers')
df_ethn
# Out:
#   Defendant Ethnicity  Numbers
# 0            HISPANIC      895
# 1        NOT HISPANIC    11035
# 2             UNKNOWN     3702

# %%
plt.figure(figsize = (10, 5))
plt.xlabel('Defendant Ethnicity')
plt.title('Arrests by Ethnicity')
plt.ylabel('Numbers')
x = df_ethn['Defendant Ethnicity']
y = df_ethn['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Defendant Ethnicity.jpg', dpi = 480)

# %%
sns.displot(df['Defendant Ethnicity'], kde = True, bins = 20)

# %%
df_race = df.groupby('Defendant Race').size().reset_index(name = 'Numbers')
df_race
# Out:
#   Defendant Race  Numbers
# 0          ASIAN       69
# 1          BLACK    13731
# 2       MULTIPLE       29
# 3          OTHER       70
# 4        UNKNOWN      364
# 5          WHITE     1369

# %%
plt.figure(figsize = (10, 5))
plt.xlabel('Defendant Race')
plt.title('Arrests by Race')
plt.ylabel('Numbers')
x = df_race['Defendant Race']
y = df_race['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Defendant Race.jpg', dpi = 480)

# %%
sns.displot(df['Defendant Race'], kde = True, bins = 20)

# %%
df_age = df.groupby('Age').size().reset_index(name = 'Numbers')
df_age
# Out:
#     Age  Numbers
# 0    18      275
# 1    19      311
# 2    20      390
# 3    21      483
# 4    22      447
# ..  ...      ...
# 64   83        1
# 65   85        1
# 66   88        1
# 67  120        4
# 68  121        1
#
# [69 rows x 2 columns]

# %%
plt.figure(figsize = (30, 10))
plt.xlabel('Age')
plt.title('Arrests by Ages')
plt.ylabel('Numbers')
x = df_age['Age']
y = df_age['Numbers']
plt.bar(x, y)
plt.grid(which = 'both', linestyle = ':')
plt.savefig('Age.jpg', dpi = 480)

# %%
sns.displot(df['Age'], kde = True, bins = 10)

# %%
df_min = df['Age'].min()
df_max = df['Age'].max()
print(df_min, df_max)
# Out:
# 18 121

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
q_1 = df['Age'].quantile(0.25)
q_3 = df['Age'].quantile(0.75)
iqr = q_3 - q_1
lower = q_1 - 1.5 * iqr
upper = q_3 + 1.5 * iqr

# %%
upper_array = np.where(df['Age'] >= upper)[0]
lower_array = np.where(df['Age'] <= lower)[0]

# %%
df.shape
# Out:
# (15632, 10)
